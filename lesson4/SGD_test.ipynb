# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol

# %%
# 目標函數(損失函數)
f = lambda x: x ** 2 - 2 * x + 1

# 目標函數的一階導數:dy/dx
# df = lambda x: 2 * x - 2
x = Symbol('x')
y = x ** 2 - 2 * x + 1
yprime = y.diff(x)
df = lambda x_value: yprime.subs(x, x_value).evalf()

# %%
# 梯度下降函數
# x_start: x的起始點
# df: 目標函數的一階導數
# epochs: 執行週期
# lr: 學習率
def GD(w_start, epochs, lr):    
    w_list = np.zeros(epochs+1)    
    w = w_start    
    w_list[0] = w    
    for i in range(epochs):         
        # w更新 w_new = w — learning_rate * gradient        
        w -= lr * df(w)         
        w_list[i+1] = w    
    return w_list

# %%
# 超參數(Hyperparameters)
w_start = 5     # 起始權重 -5, -3
epochs = 15     # 執行週期數 
lr = 0.3        # 學習率 0.01, 0.9

# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
w = GD(w_start, epochs, lr=lr) 
print('w的變化軌跡：', np.around(w, 2))

# 設定中文字型
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  
# plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] # 修改中文字體
# 矯正負號
plt.rcParams['axes.unicode_minus'] = False

color = 'r'    
t = np.arange(-6.0, 6.0, 0.01)
plt.plot(t, f(t), c='b')
plt.plot(w, f(w), c=color, label='lr={}'.format(lr))    
plt.scatter(w, f(w), c=color, ) 

plt.title('梯度下降法', fontsize=20)
plt.xlabel('W', fontsize=20)
plt.ylabel('損失函數', fontsize=20)
plt.show()
# Out:
# w的變化軌跡： [5.   2.6  1.64 1.26 1.1  1.04 1.02 1.01 1.   1.   1.   1.   1.   1.
#  1.   1.  ]

# %%
import scipy.integrate as integrate

def f(x):
    return 3*x**2
i, e = integrate.qual(lambda x: f(x), -1, 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 def f(x):
#       4     return 3*x**2
# ----> 5 i, e = integrate.qual(lambda x: f(x), -1, 2)
#
# AttributeError: module 'scipy.integrate' has no attribute 'qual'
